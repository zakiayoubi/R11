# %% [markdown]
# # SQL Tutorial in Jupyter
# **Learning Objective:** In this tutorial, you will learn to setup SQL in Jupyter Notebook and run SQL commands.

# %% [markdown]
# ❗**TODO:** Add a Markdown block below. Put the names of both partners there.

# %% [markdown]
# Below is the ERD for the Database we will be practicing with. (Chinook.db)
#
# ![chinook_schematic.jpeg](attachment:chinook_schematic.jpeg)

# %% [markdown]
# ## Setup
#
# *This is already done for you.* First, we install the python requirements from **requirements.txt**. There's lot of libraries, but most importantly, this installs the  **ipython-sql** library that enables SQL execution in Jupyter Notebooks and an older version of SQLAlchemy (1.4.46) that works with Codespaces.
#
# ❗ The command ```**%load_ext sql**``` is used to activate sql in Jupyter.
#
# ❗ The command ```**%sql sqlite:///<database_name>.db**``` is used to select the working database. (Note 3 slashes!)

# %%
# Start the Jupyter SQL engine, connecting to a SQLite database 
# %reload_ext sql 
# %sql sqlite:///chinook.db

# %% [markdown]
# ## Writing Queries
#
# The command **%%SQL** is referenced before writing an SQL query
#
# Comments must be written in SQL syntax using double dash lines: **--**
#
# **Below are a few examples:**

# %%
# %%sql
# -- This is a command that queries everything from the 'artists' table and limits the result to 5
#
# SELECT * FROM artists LIMIT 5
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'AC/DC'),
#  (2, 'Accept'),
#  (3, 'Aerosmith'),
#  (4, 'Alanis Morissette'),
#  (5, 'Alice In Chains')]

# %%
# %%sql
# -- A query that returns the name of ArtistsID #5
#
# SELECT Name FROM artists WHERE ArtistID BETWEEN 90 AND 100;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Iron Maiden',),
#  ('James Brown',),
#  ('Jamiroquai',),
#  ('JET',),
#  ('Jimi Hendrix',),
#  ('Joe Satriani',),
#  ('Jota Quest',),
#  ('João Suplicy',),
#  ('Judas Priest',),
#  ('Legião Urbana',),
#  ('Lenny Kravitz',)]

# %%
# %%sql
# -- A query that returns 10 tracks with the longest playtime
#
# SELECT name, milliseconds/1000.0/60 AS minutes, composer
# FROM  tracks
# ORDER BY milliseconds DESC lIMIT 10
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Occupation / Precipice', 88.11588333333334, None),
#  ('Through a Looking Glass', 84.81396666666666, None),
#  ('Greetings from Earth, Pt. 1', 49.33821666666667, None),
#  ('The Man With Nine Lives', 49.283300000000004, None),
#  ('Battlestar Galactica, Pt. 2', 49.26801666666667, None),
#  ('Battlestar Galactica, Pt. 1', 49.2117, None),
#  ('Murder On the Rising Star', 48.93156666666666, None),
#  ('Battlestar Galactica, Pt. 3', 48.7967, None),
#  ('Take the Celestra', 48.79461666666667, None),
#  ('Fire In Space', 48.77655, None)]

# %% [markdown]
# ## Saving commands in Variables
# Query commands can be saved in a variable using a single percentage(%) sign.

# %%
df = %sql SELECT * FROM albums WHERE ArtistID = 90
# Out:
#  * sqlite:///chinook.db
# Done.

# %%
# Queries saved in varible can be viewed by simply executing the variable name as shown below
df
# Out:
# [(94, 'A Matter of Life and Death', 90),
#  (95, 'A Real Dead One', 90),
#  (96, 'A Real Live One', 90),
#  (97, 'Brave New World', 90),
#  (98, 'Dance Of Death', 90),
#  (99, 'Fear Of The Dark', 90),
#  (100, 'Iron Maiden', 90),
#  (101, 'Killers', 90),
#  (102, 'Live After Death', 90),
#  (103, 'Live At Donington 1992 (Disc 1)', 90),
#  (104, 'Live At Donington 1992 (Disc 2)', 90),
#  (105, 'No Prayer For The Dying', 90),
#  (106, 'Piece Of Mind', 90),
#  (107, 'Powerslave', 90),
#  (108, 'Rock In Rio [CD1]', 90),
#  (109, 'Rock In Rio [CD2]', 90),
#  (110, 'Seventh Son of a Seventh Son', 90),
#  (111, 'Somewhere in Time', 90),
#  (112, 'The Number of The Beast', 90),
#  (113, 'The X Factor', 90),
#  (114, 'Virtual XI', 90)]

# %% [markdown]
# # Exercises

# %% [markdown]
# #### Ex. 1
# Write a query that returns the first and last name of customers from Brazil

# %%
# %%sql
# -- Write Your Query here
# SELECT FirstName, LastName FROM customers WHERE country = "Brazil"
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Luís', 'Gonçalves'),
#  ('Eduardo', 'Martins'),
#  ('Alexandre', 'Rocha'),
#  ('Roberto', 'Almeida'),
#  ('Fernanda', 'Ramos')]

# %% [markdown]
# #### Ex. 2
# Write a query that returns the first and last name, IDs, and countries of customers excluding the USA.

# %%
# %%sql
# -- Write Your Query here
# SELECT FirstName, LastName, CustomerId,Country FROM customers WHERE country is NOT "USA"
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Luís', 'Gonçalves', 1, 'Brazil'),
#  ('Leonie', 'Köhler', 2, 'Germany'),
#  ('François', 'Tremblay', 3, 'Canada'),
#  ('Bjørn', 'Hansen', 4, 'Norway'),
#  ('František', 'Wichterlová', 5, 'Czech Republic'),
#  ('Helena', 'Holý', 6, 'Czech Republic'),
#  ('Astrid', 'Gruber', 7, 'Austria'),
#  ('Daan', 'Peeters', 8, 'Belgium'),
#  ('Kara', 'Nielsen', 9, 'Denmark'),
#  ('Eduardo', 'Martins', 10, 'Brazil'),
#  ('Alexandre', 'Rocha', 11, 'Brazil'),
#  ('Roberto', 'Almeida', 12, 'Brazil'),
#  ('Fernanda', 'Ramos', 13, 'Brazil'),
#  ('Mark', 'Philips', 14, 'Canada'),
#  ('Jennifer', 'Peterson', 15, 'Canada'),
#  ('Robert', 'Brown', 29, 'Canada'),
#  ('Edward', 'Francis', 30, 'Canada'),
#  ('Martha', 'Silk', 31, 'Canada'),
#  ('Aaron', 'Mitchell', 32, 'Canada'),
#  ('Ellie', 'Sullivan', 33, 'Canada'),
#  ('João', 'Fernandes', 34, 'Portugal'),
#  ('Madalena', 'Sampaio', 35, 'Portugal'),
#  ('Hannah', 'Schneider', 36, 'Germany'),
#  ('Fynn', 'Zimmermann', 37, 'Germany'),
#  ('Niklas', 'Schröder', 38, 'Germany'),
#  ('Camille', 'Bernard', 39, 'France'),
#  ('Dominique', 'Lefebvre', 40, 'France'),
#  ('Marc', 'Dubois', 41, 'France'),
#  ('Wyatt', 'Girard', 42, 'France'),
#  ('Isabelle', 'Mercier', 43, 'France'),
#  ('Terhi', 'Hämäläinen', 44, 'Finland'),
#  ('Ladislav', 'Kovács', 45, 'Hungary'),
#  ('Hugh', "O'Reilly", 46, 'Ireland'),
#  ('Lucas', 'Mancini', 47, 'Italy'),
#  ('Johannes', 'Van der Berg', 48, 'Netherlands'),
#  ('Stanisław', 'Wójcik', 49, 'Poland'),
#  ('Enrique', 'Muñoz', 50, 'Spain'),
#  ('Joakim', 'Johansson', 51, 'Sweden'),
#  ('Emma', 'Jones', 52, 'United Kingdom'),
#  ('Phil', 'Hughes', 53, 'United Kingdom'),
#  ('Steve', 'Murray', 54, 'United Kingdom'),
#  ('Mark', 'Taylor', 55, 'Australia'),
#  ('Diego', 'Gutiérrez', 56, 'Argentina'),
#  ('Luis', 'Rojas', 57, 'Chile'),
#  ('Manoj', 'Pareek', 58, 'India'),
#  ('Puja', 'Srivastava', 59, 'India')]

# %% [markdown]
# #### Ex. 3
# Write a query that lists all of the unique billing countries from invoices.

# %%
# %%sql
# -- Write Your Query here
# SELECT DISTINCT BillingCountry FROM invoices
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Germany',),
#  ('Norway',),
#  ('Belgium',),
#  ('Canada',),
#  ('USA',),
#  ('France',),
#  ('Ireland',),
#  ('United Kingdom',),
#  ('Australia',),
#  ('Chile',),
#  ('India',),
#  ('Brazil',),
#  ('Portugal',),
#  ('Netherlands',),
#  ('Spain',),
#  ('Sweden',),
#  ('Czech Republic',),
#  ('Finland',),
#  ('Denmark',),
#  ('Italy',),
#  ('Poland',),
#  ('Austria',),
#  ('Hungary',),
#  ('Argentina',)]

# %% [markdown]
# #### Ex. 4
# What ten tracks require the most space. Show their name and how much space they require.

# %%
# %%sql
# -- Write Your Query here
# SELECT Name,Bytes/1024/1024 as "Megabytes" FROM tracks ORDER BY Bytes DESC LIMIT 10
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Through a Looking Glass', 1010),
#  ('Occupation / Precipice', 1005),
#  ('The Young Lords', 559),
#  ('The Man With Nine Lives', 551),
#  ('Dave', 547),
#  ('The Magnificent Warriors', 543),
#  ('The Lost Warrior', 532),
#  ('Maternity Leave', 529),
#  ('Battlestar Galactica, Pt. 3', 528),
#  ('The Woman King', 527)]

# %% [markdown]
# #### Ex. 5
# What are first name, last name, and phone numbers of customers from USA whose Support Representative has an ID number of 3?

# %%
# %%sql
# -- Write Your Query here
# SELECT FirstName, LastName, Phone FROM customers WHERE Country = 'USA' AND SupportRepId = 3
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Michelle', 'Brooks', '+1 (212) 221-3546'),
#  ('Tim', 'Goyer', '+1 (408) 996-1010'),
#  ('Frank', 'Ralston', '+1 (312) 332-3232')]

# %% [markdown]
# #### Ex. 6
# Which "sales" or "agent" employees were hired before 2003?

# %%
# %%sql
# -- Write Your Query here
# SELECT EmployeeId, LastName, FirstName FROM employees WHERE HireDate < '2003-01-01 00:00:00'
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Adams', 'Andrew'), (2, 'Edwards', 'Nancy'), (3, 'Peacock', 'Jane')]

# %% [markdown]
# #### Ex. 7
# Write a two queries to return the names and Composers of Reggae songs.
#
# Hint: Query to find the id of "reggae" music (foreign key). Use the id in another query to find names and composers of each track. You can add additional code cell blocks if needed.

# %%
# %%sql
# -- getting the id of reggae
# SELECT genreId, name FROM genres WHERE name = 'Reggae'
# Out:
#  * sqlite:///chinook.db
# Done.
# [(8, 'Reggae')]

# %%
# %%sql
# -- Write your query here
# SELECT name, composer FROM tracks WHERE genreID = 8
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Girassol', 'Bino Farias/Da Gama/Lazão/Pedro Luis/Toni Garrido'),
#  ('A Sombra Da Maldade', 'Da Gama/Toni Garrido'),
#  ('Johnny B. Goode', 'Chuck Berry'),
#  ('Soldado Da Paz', 'Herbert Vianna'),
#  ('Firmamento', 'Bino Farias/Da Gama/Henry Lawes/Lazão/Toni Garrido/Winston Foser-Vers'),
#  ('Extra', 'Gilberto Gil'),
#  ('O Erê', 'Bernardo Vilhena/Bino Farias/Da Gama/Lazão/Toni Garrido'),
#  ('Podes Crer', 'Bino Farias/Da Gama/Lazão/Toni Garrido'),
#  ('A Estrada', 'Bino Farias/Da Gama/Lazão/Toni Garrido'),
#  ('Berlim', 'Da Gama/Toni Garrido'),
#  ('Já Foi', 'Bino Farias/Da Gama/Lazão/Toni Garrido'),
#  ('Onde Você Mora?', 'Marisa Monte/Nando Reis'),
#  ('Pensamento', 'Bino Farias/Da Gamma/Lazão/Rás Bernard'),
#  ('Conciliação', 'Da Gama/Lazão/Rás Bernardo'),
#  ('Realidade Virtual', 'Bino Farias/Da Gama/Lazão/Toni Garrido'),
#  ('Mensagem', 'Bino Farias/Da Gama/Lazão/Rás Bernardo'),
#  ('A Cor Do Sol', 'Bernardo Vilhena/Da Gama/Lazão'),
#  ('Onde Você Mora?', 'Marisa Monte/Nando Reis'),
#  ('O Erê', 'Bernardo Vilhena/Bino/Da Gama/Lazao/Toni Garrido'),
#  ('A Sombra Da Maldade', 'Da Gama/Toni Garrido'),
#  ('A Estrada', 'Da Gama/Lazao/Toni Garrido'),
#  ('Falar A Verdade', 'Bino/Da Gama/Ras Bernardo'),
#  ('Firmamento', 'Harry Lawes/Winston Foster-Vers'),
#  ('Pensamento', 'Bino/Da Gama/Ras Bernardo'),
#  ('Realidade Virtual', 'Bino/Da Gamma/Lazao/Toni Garrido'),
#  ('Doutor', 'Bino/Da Gama/Toni Garrido'),
#  ('Na Frente Da TV', 'Bino/Da Gama/Lazao/Ras Bernardo'),
#  ('Downtown', 'Cidade Negra'),
#  ('Sábado A Noite', 'Lulu Santos'),
#  ('A Cor Do Sol', 'Bernardo Vilhena/Da Gama/Lazao'),
#  ('Eu Também Quero Beijar', 'Fausto Nilo/Moraes Moreira/Pepeu Gomes'),
#  ('Johnny B. Goode', None),
#  ("Don't Look Back", None),
#  ('Jah Seh No', None),
#  ("I'm The Toughest", None),
#  ('Nothing But Love', None),
#  ('Buk-In-Hamm Palace', None),
#  ('Bush Doctor', None),
#  ('Wanted Dread And Alive', None),
#  ('Mystic Man', None),
#  ('Coming In Hot', None),
#  ('Pick Myself Up', None),
#  ('Crystal Ball', None),
#  ('Equal Rights Downpresser Man', None),
#  ('Breakfast In Bed', None),
#  ('Where Did I Go Wrong', None),
#  ('I Would Do For You', None),
#  ('Homely Girl', None),
#  ('Here I Am (Come And Take Me)', None),
#  ('Kingston Town', None),
#  ('Wear You To The Ball', None),
#  ("(I Can't Help) Falling In Love With You", None),
#  ('Higher Ground', None),
#  ('Bring Me Your Cup', None),
#  ("C'est La Vie", None),
#  ('Reggae Music', None),
#  ('Superstition', None),
#  ('Until My Dying Day', None)]

# %% [markdown]
# #### Ex. 8
# Creating a sub-query: You can nest a queries inside another query, to make a more complex query!
#
# The syntax is as follows ```SELECT * FROM table WHERE column = (SELECT * FROM table WHERE condition)``` You can next any query in another query. The elegance comes in matching the output of your subquery, to the input of the outer query.
#
# Try it yourself! Do Ex. 7 again, but this time, write your two queries as a query and sub-query!

# %%
# %%sql
# -- Write your query here
# SELECT name, composer FROM tracks WHERE genreId = (SELECT genreId FROM genres WHERE name = 'Reggae')
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Girassol', 'Bino Farias/Da Gama/Lazão/Pedro Luis/Toni Garrido'),
#  ('A Sombra Da Maldade', 'Da Gama/Toni Garrido'),
#  ('Johnny B. Goode', 'Chuck Berry'),
#  ('Soldado Da Paz', 'Herbert Vianna'),
#  ('Firmamento', 'Bino Farias/Da Gama/Henry Lawes/Lazão/Toni Garrido/Winston Foser-Vers'),
#  ('Extra', 'Gilberto Gil'),
#  ('O Erê', 'Bernardo Vilhena/Bino Farias/Da Gama/Lazão/Toni Garrido'),
#  ('Podes Crer', 'Bino Farias/Da Gama/Lazão/Toni Garrido'),
#  ('A Estrada', 'Bino Farias/Da Gama/Lazão/Toni Garrido'),
#  ('Berlim', 'Da Gama/Toni Garrido'),
#  ('Já Foi', 'Bino Farias/Da Gama/Lazão/Toni Garrido'),
#  ('Onde Você Mora?', 'Marisa Monte/Nando Reis'),
#  ('Pensamento', 'Bino Farias/Da Gamma/Lazão/Rás Bernard'),
#  ('Conciliação', 'Da Gama/Lazão/Rás Bernardo'),
#  ('Realidade Virtual', 'Bino Farias/Da Gama/Lazão/Toni Garrido'),
#  ('Mensagem', 'Bino Farias/Da Gama/Lazão/Rás Bernardo'),
#  ('A Cor Do Sol', 'Bernardo Vilhena/Da Gama/Lazão'),
#  ('Onde Você Mora?', 'Marisa Monte/Nando Reis'),
#  ('O Erê', 'Bernardo Vilhena/Bino/Da Gama/Lazao/Toni Garrido'),
#  ('A Sombra Da Maldade', 'Da Gama/Toni Garrido'),
#  ('A Estrada', 'Da Gama/Lazao/Toni Garrido'),
#  ('Falar A Verdade', 'Bino/Da Gama/Ras Bernardo'),
#  ('Firmamento', 'Harry Lawes/Winston Foster-Vers'),
#  ('Pensamento', 'Bino/Da Gama/Ras Bernardo'),
#  ('Realidade Virtual', 'Bino/Da Gamma/Lazao/Toni Garrido'),
#  ('Doutor', 'Bino/Da Gama/Toni Garrido'),
#  ('Na Frente Da TV', 'Bino/Da Gama/Lazao/Ras Bernardo'),
#  ('Downtown', 'Cidade Negra'),
#  ('Sábado A Noite', 'Lulu Santos'),
#  ('A Cor Do Sol', 'Bernardo Vilhena/Da Gama/Lazao'),
#  ('Eu Também Quero Beijar', 'Fausto Nilo/Moraes Moreira/Pepeu Gomes'),
#  ('Johnny B. Goode', None),
#  ("Don't Look Back", None),
#  ('Jah Seh No', None),
#  ("I'm The Toughest", None),
#  ('Nothing But Love', None),
#  ('Buk-In-Hamm Palace', None),
#  ('Bush Doctor', None),
#  ('Wanted Dread And Alive', None),
#  ('Mystic Man', None),
#  ('Coming In Hot', None),
#  ('Pick Myself Up', None),
#  ('Crystal Ball', None),
#  ('Equal Rights Downpresser Man', None),
#  ('Breakfast In Bed', None),
#  ('Where Did I Go Wrong', None),
#  ('I Would Do For You', None),
#  ('Homely Girl', None),
#  ('Here I Am (Come And Take Me)', None),
#  ('Kingston Town', None),
#  ('Wear You To The Ball', None),
#  ("(I Can't Help) Falling In Love With You", None),
#  ('Higher Ground', None),
#  ('Bring Me Your Cup', None),
#  ("C'est La Vie", None),
#  ('Reggae Music', None),
#  ('Superstition', None),
#  ('Until My Dying Day', None)]

# %% [markdown]
# ### Ex 9
# Using sub-queries, list the tracks that are in 90's music playlist

# %%
# %%sql
# -- Write your query here
# -- SELECT name FROM tracks
#
# SELECT trackId, name FROM tracks WHERE trackId IN (SELECT trackId FROM playlist_track WHERE playlistId = (SELECT playlistId FROM playlists WHERE name LIKE '%90%Music%'))
# -- SELECT playlistId FROM playlists WHERE name = "90's Music"
# Out:
#  * sqlite:///chinook.db
# Done.
# [(3, 'Fast As a Shark'),
#  (4, 'Restless and Wild'),
#  (5, 'Princess of the Dawn'),
#  (23, 'Walk On Water'),
#  (24, 'Love In An Elevator'),
#  (25, 'Rag Doll'),
#  (26, 'What It Takes'),
#  (27, 'Dude (Looks Like A Lady)'),
#  (28, "Janie's Got A Gun"),
#  (29, "Cryin'"),
#  (30, 'Amazing'),
#  (31, 'Blind Man'),
#  (32, 'Deuces Are Wild'),
#  (33, 'The Other Side'),
#  (34, 'Crazy'),
#  (35, 'Eat The Rich'),
#  (36, 'Angel'),
#  (37, "Livin' On The Edge"),
#  (38, 'All I Really Want'),
#  (39, 'You Oughta Know'),
#  (40, 'Perfect'),
#  (41, 'Hand In My Pocket'),
#  (42, 'Right Through You'),
#  (43, 'Forgiven'),
#  (44, 'You Learn'),
#  (45, 'Head Over Feet'),
#  (46, 'Mary Jane'),
#  (47, 'Ironic'),
#  (48, 'Not The Doctor'),
#  (49, 'Wake Up'),
#  (50, 'You Oughta Know (Alternate)'),
#  (51, 'We Die Young'),
#  (52, 'Man In The Box'),
#  (53, 'Sea Of Sorrow'),
#  (54, 'Bleed The Freak'),
#  (55, "I Can't Remember"),
#  (56, 'Love, Hate, Love'),
#  (57, "It Ain't Like That"),
#  (58, 'Sunshine'),
#  (59, 'Put You Down'),
#  (60, 'Confusion'),
#  (61, 'I Know Somethin (Bout You)'),
#  (62, 'Real Thing'),
#  (77, 'Enter Sandman'),
#  (78, 'Master Of Puppets'),
#  (79, 'Harvester Of Sorrow'),
#  (80, 'The Unforgiven'),
#  (81, 'Sad But True'),
#  (82, 'Creeping Death'),
#  (83, 'Wherever I May Roam'),
#  (84, 'Welcome Home (Sanitarium)'),
#  (111, 'Money'),
#  (112, 'Long Tall Sally'),
#  (113, 'Bad Boy'),
#  (114, 'Twist And Shout'),
#  (115, 'Please Mr. Postman'),
#  (116, "C'Mon Everybody"),
#  (117, "Rock 'N' Roll Music"),
#  (118, 'Slow Down'),
#  (119, 'Roadrunner'),
#  (120, 'Carol'),
#  (121, 'Good Golly Miss Molly'),
#  (122, '20 Flight Rock'),
#  (166, 'Smoked Pork'),
#  (167, "Body Count's In The House"),
#  (168, 'Now Sports'),
#  (169, 'Body Count'),
#  (170, 'A Statistic'),
#  (171, 'Bowels Of The Devil'),
#  (172, 'The Real Problem'),
#  (173, 'KKK Bitch'),
#  (174, 'D Note'),
#  (175, 'Voodoo'),
#  (176, 'The Winner Loses'),
#  (177, 'There Goes The Neighborhood'),
#  (178, 'Oprah'),
#  (179, 'Evil Dick'),
#  (180, 'Body Count Anthem'),
#  (181, "Momma's Gotta Die Tonight"),
#  (182, 'Freedom Of Speech'),
#  (183, 'King In Crimson'),
#  (184, 'Chemical Wedding'),
#  (185, 'The Tower'),
#  (186, 'Killing Floor'),
#  (187, 'Book Of Thel'),
#  (188, 'Gates Of Urizen'),
#  (189, 'Jerusalem'),
#  (190, 'Trupets Of Jericho'),
#  (191, 'Machine Men'),
#  (192, 'The Alchemist'),
#  (193, 'Realword'),
#  (205, 'Jorge Da Capadócia'),
#  (206, 'Prenda Minha'),
#  (207, 'Meditação'),
#  (208, 'Terra'),
#  (209, 'Eclipse Oculto'),
#  (210, 'Texto "Verdade Tropical"'),
#  (211, 'Bem Devagar'),
#  (212, 'Drão'),
#  (213, 'Saudosismo'),
#  (214, 'Carolina'),
#  (215, 'Sozinho'),
#  (216, 'Esse Cara'),
#  (217, 'Mel'),
#  (218, 'Linha Do Equador'),
#  (219, 'Odara'),
#  (220, 'A Luz De Tieta'),
#  (221, 'Atrás Da Verd-E-Rosa Só Não Vai Quem Já Morreu'),
#  (222, 'Vida Boa'),
#  (246, 'Mateus Enter'),
#  (247, 'O Cidadão Do Mundo'),
#  (248, 'Etnia'),
#  (249, 'Quilombo Groove [Instrumental]'),
#  (250, 'Macô'),
#  (251, 'Um Passeio No Mundo Livre'),
#  (252, 'Samba Do Lado'),
#  (253, 'Maracatu Atômico'),
#  (254, 'O Encontro De Isaac Asimov Com Santos Dumont No Céu'),
#  (255, 'Corpo De Lama'),
#  (256, 'Sobremesa'),
#  (257, 'Manguetown'),
#  (258, 'Um Satélite Na Cabeça'),
#  (259, 'Baião Ambiental [Instrumental]'),
#  (260, 'Sangue De Bairro'),
#  (261, 'Enquanto O Mundo Explode'),
#  (262, 'Interlude Zumbi'),
#  (263, 'Criança De Domingo'),
#  (264, 'Amor De Muito'),
#  (265, 'Samidarish [Instrumental]'),
#  (266, 'Maracatu Atômico [Atomic Version]'),
#  (267, 'Maracatu Atômico [Ragga Mix]'),
#  (268, 'Maracatu Atômico [Trip Hop]'),
#  (269, 'Banditismo Por Uma Questa'),
#  (270, 'Banditismo Por Uma Questa'),
#  (271, 'Rios Pontes & Overdrives'),
#  (272, 'Cidade'),
#  (273, 'Praiera'),
#  (274, 'Samba Makossa'),
#  (275, 'Da Lama Ao Caos'),
#  (276, 'Maracatu De Tiro Certeiro'),
#  (277, 'Salustiano Song'),
#  (278, 'Antene Se'),
#  (279, 'Risoflora'),
#  (280, 'Lixo Do Mangue'),
#  (281, 'Computadores Fazem Arte'),
#  (299, 'Onde Você Mora?'),
#  (300, 'O Erê'),
#  (301, 'A Sombra Da Maldade'),
#  (302, 'A Estrada'),
#  (303, 'Falar A Verdade'),
#  (304, 'Firmamento'),
#  (305, 'Pensamento'),
#  (306, 'Realidade Virtual'),
#  (307, 'Doutor'),
#  (308, 'Na Frente Da TV'),
#  (309, 'Downtown'),
#  (310, 'Sábado A Noite'),
#  (311, 'A Cor Do Sol'),
#  (312, 'Eu Também Quero Beijar'),
#  (337, 'You Shook Me'),
#  (338, "I Can't Quit You Baby"),
#  (339, 'Communication Breakdown'),
#  (340, 'Dazed and Confused'),
#  (341, 'The Girl I Love She Got Long Black Wavy Hair'),
#  (342, 'What is and Should Never Be'),
#  (343, 'Communication Breakdown(2)'),
#  (344, 'Travelling Riverside Blues'),
#  (345, 'Whole Lotta Love'),
#  (346, "Somethin' Else"),
#  (347, 'Communication Breakdown(3)'),
#  (348, "I Can't Quit You Baby(2)"),
#  (349, 'You Shook Me(2)'),
#  (350, 'How Many More Times'),
#  (408, 'Free Speech For The Dumb'),
#  (409, "It's Electric"),
#  (410, 'Sabbra Cadabra'),
#  (411, 'Turn The Page'),
#  (412, 'Die Die My Darling'),
#  (413, 'Loverman'),
#  (414, 'Mercyful Fate'),
#  (415, 'Astronomy'),
#  (416, 'Whiskey In The Jar'),
#  (417, "Tuesday's Gone"),
#  (418, 'The More I See'),
#  (424, 'Innuendo'),
#  (428, 'Headlong'),
#  (430, "I'm Going Slightly Mad"),
#  (434, 'The Show Must Go On'),
#  (436, 'Detroit Rock City'),
#  (437, 'Black Diamond'),
#  (438, 'Hard Luck Woman'),
#  (439, 'Sure Know Something'),
#  (440, 'Love Gun'),
#  (441, 'Deuce'),
#  (442, "Goin' Blind"),
#  (443, 'Shock Me'),
#  (444, 'Do You Love Me'),
#  (445, 'She'),
#  (446, 'I Was Made For Loving You'),
#  (447, 'Shout It Out Loud'),
#  (448, 'God Of Thunder'),
#  (449, 'Calling Dr. Love'),
#  (450, 'Beth'),
#  (451, 'Strutter'),
#  (453, 'Cold Gin'),
#  (454, 'Plaster Caster'),
#  (455, "God Gave Rock 'n' Roll To You"),
#  (456, 'Heart of the Night'),
#  (457, 'De La Luz'),
#  (458, 'Westwood Moon'),
#  (459, 'Midnight'),
#  (460, 'Playtime'),
#  (461, 'Surrender'),
#  (462, "Valentino's"),
#  (463, 'Believe'),
#  (464, 'As We Sleep'),
#  (465, 'When Evening Falls'),
#  (466, 'J Squared'),
#  (467, 'Best Thing'),
#  (470, 'Longview'),
#  (471, 'Welcome To Paradise'),
#  (472, 'Basket Case'),
#  (473, 'When I Come Around'),
#  (474, 'She'),
#  (475, 'J.A.R. (Jason Andrew Relva)'),
#  (476, 'Geek Stink Breath'),
#  (477, 'Brain Stew'),
#  (478, 'Jaded'),
#  (479, 'Walking Contradiction'),
#  (480, 'Stuck With Me'),
#  (481, "Hitchin' A Ride"),
#  (482, 'Good Riddance (Time Of Your Life)'),
#  (483, 'Redundant'),
#  (484, 'Nice Guys Finish Last'),
#  (501, 'Grito De Alerta'),
#  (502, 'Não Dá Mais Pra Segurar (Explode Coração)'),
#  (503, 'Começaria Tudo Outra Vez'),
#  (504, 'O Que É O Que É ?'),
#  (505, 'Sangrando'),
#  (506, 'Diga Lá, Coração'),
#  (507, 'Lindo Lago Do Amor'),
#  (508, 'Eu Apenas Queria Que Voçê Soubesse'),
#  (509, 'Com A Perna No Mundo'),
#  (510, 'E Vamos À Luta'),
#  (511, 'Um Homem Também Chora (Guerreiro Menino)'),
#  (512, 'Comportamento Geral'),
#  (513, 'Ponto De Interrogação'),
#  (514, 'Espere Por Mim, Morena'),
#  (515, 'Meia-Lua Inteira'),
#  (516, 'Voce e Linda'),
#  (517, 'Um Indio'),
#  (518, 'Podres Poderes'),
#  (519, 'Voce Nao Entende Nada - Cotidiano'),
#  (520, 'O Estrangeiro'),
#  (521, 'Menino Do Rio'),
#  (522, 'Qualquer Coisa'),
#  (523, 'Sampa'),
#  (524, 'Queixa'),
#  (525, 'O Leaozinho'),
#  (526, 'Fora Da Ordem'),
#  (527, 'Terra'),
#  (528, 'Alegria, Alegria'),
#  (570, '(Da Le) Yaleo'),
#  (571, 'Love Of My Life'),
#  (572, 'Put Your Lights On'),
#  (573, 'Africa Bamba'),
#  (574, 'Smooth'),
#  (575, 'Do You Like The Way'),
#  (576, 'Maria Maria'),
#  (577, 'Migra'),
#  (578, 'Corazon Espinado'),
#  (579, 'Wishing It Was'),
#  (580, 'El Farol'),
#  (581, 'Primavera'),
#  (582, 'The Calling'),
#  (583, 'Solução'),
#  (584, 'Manuel'),
#  (585, 'Entre E Ouça'),
#  (586, 'Um Contrato Com Deus'),
#  (587, 'Um Jantar Pra Dois'),
#  (588, 'Vamos Dançar'),
#  (589, 'Um Love'),
#  (590, 'Seis Da Tarde'),
#  (591, 'Baixo Rio'),
#  (592, 'Sombras Do Meu Destino'),
#  (593, 'Do You Have Other Loves?'),
#  (594, 'Agora Que O Dia Acordou'),
#  (595, 'Já!!!'),
#  (596, 'A Rua'),
#  (768, 'Knocking At Your Back Door'),
#  (769, 'Bad Attitude'),
#  (770, 'Child In Time (Son Of Aleric - Instrumental)'),
#  (771, "Nobody's Home"),
#  (772, 'Black Night'),
#  (773, 'Perfect Strangers'),
#  (774, 'The Unwritten Law'),
#  (775, 'Call Of The Wild'),
#  (776, 'Hush'),
#  (777, 'Smoke On The Water'),
#  (778, 'Space Trucking'),
#  (786, 'Vavoom : Ted The Mechanic'),
#  (787, 'Loosen My Strings'),
#  (788, 'Soon Forgotten'),
#  (789, 'Sometimes I Feel Like Screaming'),
#  (790, "Cascades : I'm Not Your Lover"),
#  (791, 'The Aviator'),
#  (792, "Rosa's Cantina"),
#  (793, 'A Castle Full Of Rascals'),
#  (794, 'A Touch Away'),
#  (795, 'Hey Cisco'),
#  (796, 'Somebody Stole My Guitar'),
#  (797, 'The Purpendicular Waltz'),
#  (798, 'King Of Dreams'),
#  (799, 'The Cut Runs Deep'),
#  (800, 'Fire In The Basement'),
#  (801, 'Truth Hurts'),
#  (802, 'Breakfast In Bed'),
#  (803, 'Love Conquers All'),
#  (804, 'Fortuneteller'),
#  (805, 'Too Much Is Not Enough'),
#  (806, 'Wicked Ways'),
#  (816, 'The Battle Rages On'),
#  (817, 'Lick It Up'),
#  (818, 'Anya'),
#  (819, 'Talk About Love'),
#  (820, 'Time To Kill'),
#  (821, 'Ramshackle Man'),
#  (822, 'A Twist In The Tail'),
#  (823, 'Nasty Piece Of Work'),
#  (824, 'Solitaire'),
#  (825, "One Man's Meat"),
#  (826, 'Pour Some Sugar On Me'),
#  (827, 'Photograph'),
#  (828, 'Love Bites'),
#  (829, "Let's Get Rocked"),
#  (830, 'Two Steps Behind [Acoustic Version]'),
#  (831, 'Animal'),
#  (832, 'Heaven Is'),
#  (833, 'Rocket'),
#  (834, 'When Love & Hate Collide'),
#  (835, 'Action'),
#  (836, 'Make Love Like A Man'),
#  (837, 'Armageddon It'),
#  (838, 'Have You Ever Needed Someone So Bad'),
#  (839, 'Rock Of Ages'),
#  (840, 'Hysteria'),
#  (841, "Bringin' On The Heartbreak"),
#  (851, 'Pétala'),
#  (852, 'Meu Bem-Querer'),
#  (853, 'Cigano'),
#  (854, 'Boa Noite'),
#  (855, 'Fato Consumado'),
#  (856, 'Faltando Um Pedaço'),
#  (857, 'Álibi'),
#  (858, 'Esquinas'),
#  (859, 'Se...'),
#  (860, 'Eu Te Devoro'),
#  (861, 'Lilás'),
#  (862, 'Acelerou'),
#  (863, 'Um Amor Puro'),
#  (864, 'Samurai'),
#  (865, 'Nem Um Dia'),
#  (866, 'Oceano'),
#  (867, 'Açai'),
#  (868, 'Serrado'),
#  (869, 'Flor De Lis'),
#  (870, 'Amar É Tudo'),
#  (871, 'Azul'),
#  (872, 'Seduzir'),
#  (873, 'A Carta'),
#  (874, 'Sina'),
#  (875, 'Acelerou'),
#  (876, 'Um Amor Puro'),
#  (891, 'Layla'),
#  (892, 'Badge'),
#  (893, 'I Feel Free'),
#  (894, 'Sunshine Of Your Love'),
#  (895, 'Crossroads'),
#  (896, 'Strange Brew'),
#  (897, 'White Room'),
#  (898, 'Bell Bottom Blues'),
#  (899, 'Cocaine'),
#  (900, 'I Shot The Sheriff'),
#  (901, 'After Midnight'),
#  (902, 'Swing Low Sweet Chariot'),
#  (903, 'Lay Down Sally'),
#  (904, 'Knockin On Heavens Door'),
#  (905, 'Wonderful Tonight'),
#  (906, 'Let It Grow'),
#  (907, 'Promises'),
#  (908, "I Can't Stand It"),
#  (909, 'Signe'),
#  (910, 'Before You Accuse Me'),
#  (911, 'Hey Hey'),
#  (912, 'Tears In Heaven'),
#  (913, 'Lonely Stranger'),
#  (914, "Nobody Knows You When You're Down & Out"),
#  (915, 'Layla'),
#  (916, 'Running On Faith'),
#  (917, "Walkin' Blues"),
#  (918, 'Alberta'),
#  (919, 'San Francisco Bay Blues'),
#  (920, 'Malted Milk'),
#  (921, 'Old Love'),
#  (922, "Rollin' And Tumblin'"),
#  (923, 'Collision'),
#  (924, 'Stripsearch'),
#  (925, 'Last Cup Of Sorrow'),
#  (926, 'Naked In Front Of The Computer'),
#  (927, 'Helpless'),
#  (928, 'Mouth To Mouth'),
#  (929, 'Ashes To Ashes'),
#  (930, 'She Loves Me Not'),
#  (931, 'Got That Feeling'),
#  (932, 'Paths Of Glory'),
#  (933, 'Home Sick Home'),
#  (934, 'Pristina'),
#  (935, 'Land Of Sunshine'),
#  (936, 'Caffeine'),
#  (937, 'Midlife Crisis'),
#  (938, 'RV'),
#  (939, 'Smaller And Smaller'),
#  (940, "Everything's Ruined"),
#  (941, 'Malpractice'),
#  (942, 'Kindergarten'),
#  (943, 'Be Aggressive'),
#  (944, 'A Small Victory'),
#  (945, 'Crack Hitler'),
#  (946, 'Jizzlobber'),
#  (947, 'Midnight Cowboy'),
#  (948, 'Easy'),
#  (949, 'Get Out'),
#  (950, 'Ricochet'),
#  (951, 'Evidence'),
#  (952, 'The Gentle Art Of Making Enemies'),
#  (953, 'Star A.D.'),
#  (954, 'Cuckoo For Caca'),
#  (955, 'Caralho Voador'),
#  (956, 'Ugly In The Morning'),
#  (957, 'Digging The Grave'),
#  (958, 'Take This Bottle'),
#  (959, 'King For A Day'),
#  (960, 'What A Day'),
#  (961, 'The Last To Know'),
#  (962, 'Just A Man'),
#  (963, 'Absolute Zero'),
#  (976, 'Falamansa Song'),
#  (977, 'Xote Dos Milagres'),
#  (978, 'Rindo À Toa'),
#  (979, 'Confidência'),
#  (984, 'Asas'),
#  (1020, 'Doll'),
#  (1021, 'Monkey Wrench'),
#  (1022, 'Hey, Johnny Park!'),
#  (1023, 'My Poor Brain'),
#  (1024, 'Wind Up'),
#  (1025, 'Up In Arms'),
#  (1026, 'My Hero'),
#  (1027, 'See You'),
#  (1028, 'Enough Space'),
#  (1029, 'February Stars'),
#  (1030, 'Everlong'),
#  (1031, 'Walking After You'),
#  (1032, 'New Way Home'),
#  (1057, 'Entrando Na Sua (Intro)'),
#  (1058, 'Nervosa'),
#  (1059, 'Funk De Bamba (Com Fernanda Abreu)'),
#  (1060, 'Call Me At Cleo´s'),
#  (1061, 'Olhos Coloridos (Com Sandra De Sá)'),
#  (1062, 'Zambação'),
#  (1063, 'Funk Hum'),
#  (1064, 'Forty Days (Com DJ Hum)'),
#  (1065, 'Balada Da Paula'),
#  (1066, 'Dujji'),
#  (1067, 'Meu Guarda-Chuva'),
#  (1068, 'Motéis'),
#  (1069, 'Whistle Stop'),
#  (1070, '16 Toneladas'),
#  (1071, 'Divirta-Se (Saindo Da Sua)'),
#  (1072, 'Forty Days Instrumental'),
#  (1087, 'Introdução (Live)'),
#  (1088, 'Palco (Live)'),
#  (1089, 'Is This Love (Live)'),
#  (1090, 'Stir It Up (Live)'),
#  (1091, 'Refavela (Live)'),
#  (1092, 'Vendedor De Caranguejo (Live)'),
#  (1093, 'Quanta (Live)'),
#  (1094, 'Estrela (Live)'),
#  (1095, 'Pela Internet (Live)'),
#  (1096, 'Cérebro Eletrônico (Live)'),
#  (1097, 'Opachorô (Live)'),
#  (1098, 'Copacabana (Live)'),
#  (1099, 'A Novidade (Live)'),
#  (1100, 'Ghandi (Live)'),
#  (1101, 'De Ouro E Marfim (Live)'),
#  (1105, 'A Novidade'),
#  (1106, 'Tenho Sede'),
#  (1107, 'Refazenda'),
#  (1108, 'Realce'),
#  (1109, 'Esotérico'),
#  (1110, 'Drão'),
#  (1111, 'A Paz'),
#  (1112, 'Beira Mar'),
#  (1113, 'Sampa'),
#  (1114, 'Parabolicamará'),
#  (1115, 'Tempo Rei'),
#  (1116, 'Expresso 2222'),
#  (1117, 'Aquele Abraço'),
#  (1118, 'Palco'),
#  (1119, 'Toda Menina Baiana'),
#  (1120, 'Sítio Do Pica-Pau Amarelo'),
#  (1158, 'Right Next Door to Hell'),
#  (1159, "Dust N' Bones"),
#  (1160, 'Live and Let Die'),
#  (1161, "Don't Cry (Original)"),
#  (1162, 'Perfect Crime'),
#  (1163, "You Ain't the First"),
#  (1164, 'Bad Obsession'),
#  (1165, 'Back off Bitch'),
#  (1166, "Double Talkin' Jive"),
#  (1167, 'November Rain'),
#  (1168, 'The Garden'),
#  (1169, 'Garden of Eden'),
#  (1170, "Don't Damn Me"),
#  (1171, 'Bad Apples'),
#  (1172, 'Dead Horse'),
#  (1173, 'Coma'),
#  (1174, 'Civil War'),
#  (1175, '14 Years'),
#  (1176, 'Yesterdays'),
#  (1177, "Knockin' On Heaven's Door"),
#  (1178, 'Get In The Ring'),
#  (1179, 'Shotgun Blues'),
#  (1180, 'Breakdown'),
#  (1181, 'Pretty Tied Up'),
#  (1182, 'Locomotive'),
#  (1183, 'So Fine'),
#  (1184, 'Estranged'),
#  (1185, 'You Could Be Mine'),
#  (1186, "Don't Cry"),
#  (1187, 'My World'),
#  (1188, 'Colibri'),
#  (1189, 'Love Is The Colour'),
#  (1190, 'Magnetic Ocean'),
#  (1191, 'Deep Waters'),
#  (1192, "L'Arc En Ciel De Miles"),
#  (1193, 'Gypsy'),
#  (1194, 'Journey Into Sunlight'),
#  (1195, 'Sunchild'),
#  (1196, 'Millenium'),
#  (1197, "Thinking 'Bout Tomorrow"),
#  (1198, "Jacob's Ladder"),
#  (1199, 'She Wears Black'),
#  (1200, 'Dark Side Of The Cog'),
#  (1212, 'The Number Of The Beast'),
#  (1213, 'The Trooper'),
#  (1214, 'Prowler'),
#  (1215, 'Transylvania'),
#  (1216, 'Remember Tomorrow'),
#  (1217, 'Where Eagles Dare'),
#  (1218, 'Sanctuary'),
#  (1219, 'Running Free'),
#  (1220, 'Run To The Hilss'),
#  (1221, '2 Minutes To Midnight'),
#  (1222, 'Iron Maiden'),
#  (1223, 'Hallowed Be Thy Name'),
#  (1224, 'Be Quick Or Be Dead'),
#  (1225, 'From Here To Eternity'),
#  (1226, 'Can I Play With Madness'),
#  (1227, 'Wasting Love'),
#  (1228, 'Tailgunner'),
#  (1229, 'The Evil That Men Do'),
#  (1230, 'Afraid To Shoot Strangers'),
#  (1231, 'Bring Your Daughter... To The Slaughter'),
#  (1232, 'Heaven Can Wait'),
#  (1233, 'The Clairvoyant'),
#  (1234, 'Fear Of The Dark'),
#  (1256, 'Be Quick Or Be Dead'),
#  (1257, 'From Here To Eternity'),
#  (1258, 'Afraid To Shoot Strangers'),
#  (1259, 'Fear Is The Key'),
#  (1260, "Childhood's End"),
#  (1261, 'Wasting Love'),
#  (1262, 'The Fugitive'),
#  (1263, 'Chains Of Misery'),
#  (1264, 'The Apparition'),
#  (1265, 'Judas Be My Guide'),
#  (1266, 'Weekend Warrior'),
#  (1267, 'Fear Of The Dark'),
#  (1305, 'Be Quick Or Be Dead'),
#  (1306, 'The Number Of The Beast'),
#  (1307, 'Wrathchild'),
#  (1308, 'From Here To Eternity'),
#  (1309, 'Can I Play With Madness'),
#  (1310, 'Wasting Love'),
#  (1311, 'Tailgunner'),
#  (1312, 'The Evil That Men Do'),
#  (1313, 'Afraid To Shoot Strangers'),
#  (1314, 'Fear Of The Dark'),
#  (1315, 'Bring Your Daughter... To The Slaughter...'),
#  (1316, 'The Clairvoyant'),
#  (1317, 'Heaven Can Wait'),
#  (1318, 'Run To The Hills'),
#  (1319, '2 Minutes To Midnight'),
#  (1320, 'Iron Maiden'),
#  (1321, 'Hallowed Be Thy Name'),
#  (1322, 'The Trooper'),
#  (1323, 'Sanctuary'),
#  (1324, 'Running Free'),
#  (1325, 'Tailgunner'),
#  (1326, 'Holy Smoke'),
#  (1327, 'No Prayer For The Dying'),
#  (1328, 'Public Enema Number One'),
#  (1329, 'Fates Warning'),
#  (1330, 'The Assassin'),
#  (1331, 'Run Silent Run Deep'),
#  (1332, 'Hooks In You'),
#  (1333, 'Bring Your Daughter... ...To The Slaughter'),
#  (1334, 'Mother Russia'),
#  (1395, 'Sign Of The Cross'),
#  (1396, 'Lord Of The Flies'),
#  (1397, 'Man On The Edge'),
#  (1398, 'Fortunes Of War'),
#  (1399, 'Look For The Truth'),
#  (1400, 'The Aftermath'),
#  (1401, 'Judgement Of Heaven'),
#  (1402, "Blood On The World's Hands"),
#  (1403, 'The Edge Of Darkness'),
#  (1404, '2 A.M.'),
#  (1405, 'The Unbeliever'),
#  (1406, 'Futureal'),
#  (1407, 'The Angel And The Gambler'),
#  (1408, 'Lightning Strikes Twice'),
#  (1409, 'The Clansman'),
#  (1410, 'When Two Worlds Collide'),
#  (1411, 'The Educated Fool'),
#  (1412, "Don't Look To The Eyes Of A Stranger"),
#  (1413, 'Como Estais Amigos'),
#  (1414, 'Please Please Please'),
#  (1415, 'Think'),
#  (1416, 'Night Train'),
#  (1417, 'Out Of Sight'),
#  (1418, "Papa's Got A Brand New Bag Pt.1"),
#  (1419, 'I Got You (I Feel Good)'),
#  (1420, "It's A Man's Man's Man's World"),
#  (1421, 'Cold Sweat'),
#  (1422, "Say It Loud, I'm Black And I'm Proud Pt.1"),
#  (1423, 'Get Up (I Feel Like Being A) Sex Machine'),
#  (1424, 'Hey America'),
#  (1425, 'Make It Funky Pt.1'),
#  (1426, "I'm A Greedy Man Pt.1"),
#  (1427, 'Get On The Good Foot'),
#  (1428, 'Get Up Offa That Thing'),
#  (1429, "It's Too Funky In Here"),
#  (1430, 'Living In America'),
#  (1431, "I'm Real"),
#  (1432, 'Hot Pants Pt.1'),
#  (1433, 'Soul Power (Live)'),
#  (1434, 'When You Gonna Learn (Digeridoo)'),
#  (1435, 'Too Young To Die'),
#  (1436, 'Hooked Up'),
#  (1437, 'If I Like It, I Do It'),
#  (1438, 'Music Of The Wind'),
#  (1439, 'Emergency On Planet Earth'),
#  (1440, "Whatever It Is, I Just Can't Stop"),
#  (1441, 'Blow Your Mind'),
#  (1442, 'Revolution 1993'),
#  (1443, "Didgin' Out"),
#  (1444, 'Canned Heat'),
#  (1445, 'Planet Home'),
#  (1446, 'Black Capricorn Day'),
#  (1447, 'Soul Education'),
#  (1448, 'Failling'),
#  (1449, 'Destitute Illusions'),
#  (1450, 'Supersonic'),
#  (1451, 'Butterfly'),
#  (1452, 'Were Do We Go From Here'),
#  (1453, 'King For A Day'),
#  (1454, 'Deeper Underground'),
#  (1455, 'Just Another Story'),
#  (1456, 'Stillness In Time'),
#  (1457, 'Half The Man'),
#  (1458, 'Light Years'),
#  (1459, 'Manifest Destiny'),
#  (1460, 'The Kids'),
#  (1461, 'Mr. Moon'),
#  (1462, 'Scam'),
#  (1463, 'Journey To Arnhemland'),
#  (1464, 'Morning Glory'),
#  (1465, 'Space Cowboy'),
#  (1496, 'Surfing with the Alien'),
#  (1497, 'Ice 9'),
#  (1498, 'Crushing Day'),
#  (1499, 'Always With Me, Always With You'),
#  (1500, 'Satch Boogie'),
#  (1501, 'Hill of the Skull'),
#  (1502, 'Circles'),
#  (1503, 'Lords of Karma'),
#  (1504, 'Midnight'),
#  (1505, 'Echo'),
#  (1520, 'Rapidamente'),
#  (1521, 'As Dores do Mundo'),
#  (1522, 'Vou Pra Ai'),
#  (1523, 'My Brother'),
#  (1524, 'Há Quanto Tempo'),
#  (1525, 'Vício'),
#  (1526, 'Encontrar Alguém'),
#  (1527, 'Dance Enquanto é Tempo'),
#  (1528, 'A Tarde'),
#  (1529, 'Always Be All Right'),
#  (1530, 'Sem Sentido'),
#  (1531, 'Onibusfobia'),
#  (1557, 'Metal Meltdown'),
#  (1562, "Comin' Home"),
#  (1563, 'Plaster Caster'),
#  (1564, "Goin' Blind"),
#  (1565, 'Do You Love Me'),
#  (1566, 'Domino'),
#  (1567, 'Sure Know Something'),
#  (1568, 'A World Without Heroes'),
#  (1569, 'Rock Bottom'),
#  (1570, 'See You Tonight'),
#  (1571, 'I Still Love You'),
#  (1572, 'Every Time I Look At You'),
#  (1573, '2,000 Man'),
#  (1574, 'Beth'),
#  (1575, "Nothin' To Lose"),
#  (1576, 'Rock And Roll All Nite'),
#  (1577, 'Immigrant Song'),
#  (1578, 'Heartbreaker'),
#  (1579, "Since I've Been Loving You"),
#  (1580, 'Black Dog'),
#  (1581, 'Dazed And Confused'),
#  (1582, 'Stairway To Heaven'),
#  (1583, 'Going To California'),
#  (1584, "That's The Way"),
#  (1585, 'Whole Lotta Love (Medley)'),
#  (1586, 'Thank You'),
#  (1671, 'Natália'),
#  (1672, "L'Avventura"),
#  (1673, 'Música De Trabalho'),
#  (1674, 'Longe Do Meu Lado'),
#  (1675, 'A Via Láctea'),
#  (1676, 'Música Ambiente'),
#  (1677, 'Aloha'),
#  (1678, 'Soul Parsifal'),
#  (1679, 'Dezesseis'),
#  (1680, 'Mil Pedaços'),
#  (1681, 'Leila'),
#  (1682, '1º De Julho'),
#  (1683, 'Esperando Por Mim'),
#  (1684, 'Quando Você Voltar'),
#  (1685, 'O Livro Dos Dias'),
#  (1686, 'Será'),
#  (1687, 'Ainda É Cedo'),
#  (1688, 'Geração Coca-Cola'),
#  (1689, 'Eduardo E Mônica'),
#  (1690, 'Tempo Perdido'),
#  (1691, 'Indios'),
#  (1692, 'Que País É Este'),
#  (1693, 'Faroeste Caboclo'),
#  (1694, 'Há Tempos'),
#  (1695, 'Pais E Filhos'),
#  (1696, 'Meninos E Meninas'),
#  (1697, 'Vento No Litoral'),
#  (1698, 'Perfeição'),
#  (1699, 'Giz'),
#  (1700, 'Dezesseis'),
#  (1701, 'Antes Das Seis'),
#  (1801, 'Enter Sandman'),
#  (1802, 'Sad But True'),
#  (1803, 'Holier Than Thou'),
#  (1804, 'The Unforgiven'),
#  (1805, 'Wherever I May Roam'),
#  (1806, "Don't Tread On Me"),
#  (1807, 'Through The Never'),
#  (1808, 'Nothing Else Matters'),
#  (1809, 'Of Wolf And Man'),
#  (1810, 'The God That Failed'),
#  (1811, 'My Friend Of Misery'),
#  (1812, 'The Struggle Within'),
#  (1813, 'Helpless'),
#  (1814, 'The Small Hours'),
#  (1815, 'The Wait'),
#  (1816, 'Crash Course In Brain Surgery'),
#  (1817, 'Last Caress/Green Hell'),
#  (1818, 'Am I Evil?'),
#  (1819, 'Blitzkrieg'),
#  (1820, 'Breadfan'),
#  (1821, 'The Prince'),
#  (1822, 'Stone Cold Crazy'),
#  (1823, 'So What'),
#  (1824, 'Killing Time'),
#  (1825, 'Overkill'),
#  (1826, 'Damage Case'),
#  (1827, 'Stone Dead Forever'),
#  (1828, 'Too Late Too Late'),
#  (1839, "Ain't My Bitch"),
#  (1840, '2 X 4'),
#  (1841, 'The House Jack Built'),
#  (1842, 'Until It Sleeps'),
#  (1843, 'King Nothing'),
#  (1844, 'Hero Of The Day'),
#  (1845, 'Bleeding Me'),
#  (1846, 'Cure'),
#  (1847, 'Poor Twisted Me'),
#  (1848, 'Wasted My Hate'),
#  (1849, 'Mama Said'),
#  (1850, 'Thorn Within'),
#  (1851, 'Ronnie'),
#  (1852, 'The Outlaw Torn'),
#  (1861, 'Fuel'),
#  (1862, 'The Memory Remains'),
#  (1863, "Devil's Dance"),
#  (1864, 'The Unforgiven II'),
#  (1865, 'Better Than You'),
#  (1866, 'Slither'),
#  (1867, 'Carpe Diem Baby'),
#  (1868, 'Bad Seed'),
#  (1869, 'Where The Wild Things Are'),
#  (1870, 'Prince Charming'),
#  (1871, "Low Man's Lyric"),
#  (1872, 'Attitude'),
#  (1873, 'Fixxxer'),
#  (1969, 'Bitter Pill'),
#  (1970, 'Enslaved'),
#  (1971, 'Girls, Girls, Girls'),
#  (1972, 'Kickstart My Heart'),
#  (1973, 'Wild Side'),
#  (1974, 'Glitter'),
#  (1975, 'Dr. Feelgood'),
#  (1976, "Same Ol' Situation"),
#  (1977, 'Home Sweet Home'),
#  (1978, 'Afraid'),
#  (1979, "Don't Go Away Mad (Just Go Away)"),
#  (1980, 'Without You'),
#  (1981, "Smokin' in The Boys Room"),
#  (1982, 'Primal Scream'),
#  (1983, 'Too Fast For Love'),
#  (1984, 'Looks That Kill'),
#  (1985, 'Shout At The Devil'),
#  (1986, 'Intro'),
#  (1987, 'School'),
#  (1988, 'Drain You'),
#  (1989, 'Aneurysm'),
#  (1990, 'Smells Like Teen Spirit'),
#  (1991, 'Been A Son'),
#  (1992, 'Lithium'),
#  (1993, 'Sliver'),
#  (1994, 'Spank Thru'),
#  (1995, 'Scentless Apprentice'),
#  (1996, 'Heart-Shaped Box'),
#  (1997, 'Milk It'),
#  (1998, 'Negative Creep'),
#  (1999, 'Polly'),
#  (2000, 'Breed'),
#  (2001, "Tourette's"),
#  (2002, 'Blew'),
#  (2003, 'Smells Like Teen Spirit'),
#  (2004, 'In Bloom'),
#  (2005, 'Come As You Are'),
#  (2006, 'Breed'),
#  (2007, 'Lithium'),
#  (2008, 'Polly'),
#  (2009, 'Territorial Pissings'),
#  (2010, 'Drain You'),
#  (2011, 'Lounge Act'),
#  (2012, 'Stay Away'),
#  (2013, 'On A Plain'),
#  (2014, 'Something In The Way'),
#  (2044, 'Vulcão Dub - Fui Eu'),
#  (2045, 'O Trem Da Juventude'),
#  (2046, 'Manguetown'),
#  (2047, 'Um Amor, Um Lugar'),
#  (2048, 'Bora-Bora'),
#  (2049, 'Vai Valer'),
#  (2050, 'I Feel Good (I Got You) - Sossego'),
#  (2051, 'Uns Dias'),
#  (2052, 'Sincero Breu'),
#  (2053, 'Meu Erro'),
#  (2054, 'Selvagem'),
#  (2055, 'Brasília 5:31'),
#  (2056, 'Tendo A Lua'),
#  (2057, 'Que País É Este'),
#  (2058, 'Navegar Impreciso'),
#  (2059, 'Feira Moderna'),
#  (2060, 'Tequila - Lourinha Bombril (Parate Y Mira)'),
#  (2061, 'Vamo Batê Lata'),
#  (2062, 'Life During Wartime'),
#  (2063, 'Nebulosa Do Amor'),
#  (2064, 'Caleidoscópio'),
#  (2113, 'Shining In The Light'),
#  (2114, 'When The World Was Young'),
#  (2115, 'Upon A Golden Horse'),
#  (2116, 'Blue Train'),
#  (2117, 'Please Read The Letter'),
#  (2118, 'Most High'),
#  (2119, 'Heart In Your Hand'),
#  (2120, 'Walking Into Clarksdale'),
#  (2121, 'Burning Up'),
#  (2122, 'When I Was A Child'),
#  (2123, 'House Of Love'),
#  (2124, 'Sons Of Freedom'),
#  (2125, 'United Colours'),
#  (2126, 'Slug'),
#  (2127, 'Your Blue Room'),
#  (2128, 'Always Forever Now'),
#  (2129, 'A Different Kind Of Blue'),
#  (2130, 'Beach Sequence'),
#  (2131, 'Miss Sarajevo'),
#  (2132, 'Ito Okashi'),
#  (2133, 'One Minute Warning'),
#  (2134, 'Corpse (These Chains Are Way Too Long)'),
#  (2135, 'Elvis Ate America'),
#  (2136, 'Plot 180'),
#  (2137, 'Theme From The Swan'),
#  (2138, "Theme From Let's Go Native"),
#  (2149, 'Corduroy'),
#  (2150, 'Given To Fly'),
#  (2151, 'Hail, Hail'),
#  (2152, 'Daughter'),
#  (2153, 'Elderly Woman Behind The Counter In A Small Town'),
#  (2154, 'Untitled'),
#  (2155, 'MFC'),
#  (2156, 'Go'),
#  (2157, 'Red Mosquito'),
#  (2158, 'Even Flow'),
#  (2159, 'Off He Goes'),
#  (2160, 'Nothingman'),
#  (2161, 'Do The Evolution'),
#  (2162, 'Better Man'),
#  (2163, 'Black'),
#  (2164, "F*Ckin' Up"),
#  (2193, 'Once'),
#  (2194, 'Evenflow'),
#  (2195, 'Alive'),
#  (2196, 'Why Go'),
#  (2197, 'Black'),
#  (2198, 'Jeremy'),
#  (2199, 'Oceans'),
#  (2200, 'Porch'),
#  (2201, 'Garden'),
#  (2202, 'Deep'),
#  (2203, 'Release'),
#  (2204, 'Go'),
#  (2205, 'Animal'),
#  (2206, 'Daughter'),
#  (2207, 'Glorified G'),
#  (2208, 'Dissident'),
#  (2209, 'W.M.A.'),
#  (2210, 'Blood'),
#  (2211, 'Rearviewmirror'),
#  (2212, 'Rats'),
#  (2213, 'Elderly Woman Behind The Counter In A Small Town'),
#  (2214, 'Leash'),
#  (2215, 'Indifference'),
#  (2238, 'ZeroVinteUm'),
#  (2239, 'Queimando Tudo'),
#  (2240, 'Hip Hop Rio'),
#  (2241, 'Bossa'),
#  (2242, '100% HardCore'),
#  (2243, 'Biruta'),
#  (2244, 'Mão Na Cabeça'),
#  (2245, 'O Bicho Tá Pregando'),
#  (2246, 'Adoled (Ocean)'),
#  (2247, 'Seus Amigos'),
#  (2248, 'Paga Pau'),
#  (2249, 'Rappers Reais'),
#  (2250, 'Nega Do Cabelo Duro'),
#  (2251, 'Hemp Family'),
#  (2252, 'Quem Me Cobrou?'),
#  (2253, 'Se Liga'),
#  (2282, 'Shiny Happy People'),
#  (2283, 'Me In Honey'),
#  (2284, 'Radio Song'),
#  (2296, 'How The West Was Won And Where It Got Us'),
#  (2297, 'The Wake-Up Bomb'),
#  (2298, 'New Test Leper'),
#  (2299, 'Undertow'),
#  (2300, 'E-Bow The Letter'),
#  (2301, 'Leave'),
#  (2302, 'Departure'),
#  (2303, 'Bittersweet Me'),
#  (2304, 'Be Mine'),
#  (2305, 'Binky The Doormat'),
#  (2306, 'Zither'),
#  (2307, 'So Fast, So Numb'),
#  (2308, 'Low Desert'),
#  (2309, 'Electrolite'),
#  (2310, 'Losing My Religion'),
#  (2311, 'Low'),
#  (2312, 'Near Wild Heaven'),
#  (2313, 'Endgame'),
#  (2314, 'Belong'),
#  (2315, 'Half A World Away'),
#  (2316, 'Texarkana'),
#  (2317, 'Country Feedback'),
#  (2334, 'Infeliz Natal'),
#  (2335, 'A Sua'),
#  (2336, 'Papeau Nuky Doe'),
#  ...]

# %% [markdown]
# #### Ex. 10
# Write a query to find the ArtistID of the album "Facelift" and use the result to find the name of artist

# %%
# %%sql
# SELECT name FROM artists WHERE artistId = (SELECT artistId FROM albums WHERE title = 'Facelift')
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Alice In Chains',)]

# %% [markdown]
# ### Reflection and Questions
#
# Consider the schema design of the Chinook database. What aspects of the design made it easy for you to retrieve the data you wanted? What aspects make it more difficult?
#
# - Primary and Foreign Keys: There's a clear definition of primary and foreign keys
# - Table Naming Convention: The names of the tables are straightforward and reflective of the data they contain, which aids in understanding the schema structure quickly.
#
#
# What remaining or new questions do you have?
#
# - Additional Attributes Hidden: Some tables indicate "more columns..." without specifying them, making it difficult to fully understand what data is available without additional documentation.

# %% [markdown]
# ### Submission: Commit and Push your Completed Exercises
